# %% [markdown]
# # Queremos verificar la variable que servirá para estudiar los datos a nivel de hoagar y persona

# %%
# Importar paquetes 

import pandas as pd
import pyreadstat as pyd

# %%
# Crear dfs para los módulos 

df_persona, meta_p = pyd.read_sav('Data/Enemdu_2020/enemdu_persona_2020_12.sav', apply_value_formats=True)
df_consumidor, meta_c = pyd.read_sav('Data/Enemdu_2020/enemdu_consumidor_2020_12.sav', apply_value_formats=True)
df_vivienda, meta_v = pyd.read_sav('Data/Enemdu_2020/enemdu_vivienda_hogar_2020_12.sav', apply_value_formats=True)

# %%
# Identificar nombres de variables

meta_p.column_names_to_labels
# Out:
# {'area': 'Area',
#  'ciudad': 'Ciudad',
#  'conglomerado': 'Conglomerado',
#  'panelm': 'Panelm',
#  'vivienda': 'Vivienda',
#  'hogar': 'Hogar',
#  'p01': 'Persona',
#  'p02': 'Sexo',
#  'p03': 'Edad',
#  'p04': 'Relación de parentesco',
#  'p05a': 'Seguro Social - Alternativa 1',
#  'p05b': 'Seguro Social - Alternativa 2',
#  'p06': 'Estado civil',
#  'p07': 'Asiste a clases',
#  'p08': 'Jornada a la que asiste',
#  'p08a': 'Modalidad de estudio a la que asiste',
#  'p08b': 'Tipo de conexión para actividades educativas',
#  'p09': 'Razón por la que no asiste',
#  'p10a': 'Nivel de instrucción',
#  'p10b': 'Año aprobado',
#  'p11': 'Sabe leer y escribir',
#  'p12a': 'Por sus estudios obtuvo algún título',
#  'p12b': 'Qué título obtuvo',
#  'p15': 'Cómo se considera',
#  'p15aa': 'Donde nació',
#  'p15ab': 'Lugar de nacimiento',
#  'cod_inf': 'Código del Informante',
#  'p20': 'Trabajó la semana pasada',
#  'p21': 'Actividad que realizó para ayudar en su hogar',
#  'p22': 'Tiene trabajo del cual estuvo ausente',
#  'p23': 'Razón por la que no trabajó',
#  'p231': 'Razón relacionada con el COVID19',
#  'p232': 'Continua(ó) recibiendo algún ingreso durante ausencia del trabajo',
#  'p233': 'Desde que dejó de trabajar hasta que espera regresar ¿Cuánto tiempo estará (...) ausente',
#  'p24': 'Horas de trabajo en la semana anterior',
#  'p25': 'Razón por la que trabajó menos de 40 horas',
#  'p251': 'Razón relacionada con el COVID19',
#  'p26': 'Razón por la que trabajó más de 40 horas',
#  'p27': 'Desea trabajar más horas',
#  'p28': 'Está disponible para trabajar horas adicionales',
#  'p29': 'Cuántas horas a la semana estaría disponible para trabajar',
#  'p30': 'Gestión realizada para cambiar la situación actual de trabajo',
#  'p31': 'Razón por la que busca cambiar la situación actual de trabajo',
#  'p32': 'Buscó trabajo el mes anterior',
#  'p33': 'Semanas que busca trabajo',
#  'p34': 'Razón por la que no buscó trabajo',
#  'p341': 'Razón relacionada con el COVID19',
#  'p35': 'Desea trabajar y está dispuesto a hacerlo',
#  'p351': 'Razón relacionada con el COVID19',
#  'p36': 'Condición de inactividad',
#  'p37': 'Trabajó anteriormente',
#  'p38': 'Motivos por los que dejó de trabajar',
#  'p381': 'Razón relacionada con el COVID19',
#  'p39': 'Número de semanas que no trabaja',
#  'p40': 'Rama de actividad',
#  'p41': 'Grupo de ocupación',
#  'p42': 'Categoría de ocupación',
#  'p42a': 'Es socio de cooperativa o asociación',
#  'p43': 'El trabajo que tiene es',
#  'p44a': 'Recibe alimentación',
#  'p44b': 'Recibe vivienda',
#  'p44c': 'Recibe transporte',
#  'p44d': 'Recibe vacaciones',
#  'p44e': 'Recibe ropa de trabajo',
#  'p44f': 'Recibe seguro social',
#  'p44g': 'Recibe seguro médico',
#  'p44h': 'Recibe guardería',
#  'p44i': 'Recibe cursos de capacitación',
#  'p44j': 'Recibe 13er sueldo',
#  'p44k': 'Recibe 14to sueldo',
#  'p45': 'Cuántos años trabaja',
#  'p46': 'Sitio de trabajo',
#  'p47a': 'Tamaño del establecimiento',
#  'p47b': 'Número personas trabajan en el establecimiento',
#  'p48': 'En el establecimiento se lleva',
#  'p49': 'El establecimiento tiene RUC',
#  'p50': 'Número de trabajos',
#  'p51a': 'Horas de trabajo principal',
#  'p51b': 'Horas de trabajo secundario',
#  'p51c': 'Horas de otros trabajos',
#  'p52': 'Rama de actividad - trabajo secundario',
#  'p53': 'Grupo de ocupación - trabajo secundario',
#  'p54': 'Categoría de ocupación - trabajo secundario',
#  'p54a': 'Es socio de cooperativa o asociación - trabajo secundario',
#  'p55': 'Sitio de trabajo secundario',
#  'p56a': 'Tamaño establecimiento - trabajo secundario',
#  'p56b': 'Personas que trabajan - trabajo secundario',
#  'p57': 'En el establecimiento de trabajo secundario se lleva',
#  'p58': 'El establecimiento de trabajo secundario tiene RUC',
#  'p59': 'Cómo se siente en su trabajo',
#  'p60a': 'Descontento por ingresos bajos',
#  'p60b': 'Descontento por muchas horas de trabajo',
#  'p60c': 'Descontento por horarios inconvenientes',
#  'p60d': 'Descontento por sobrecarga de trabajo',
#  'p60e': 'Descontento por no tener estabilidad',
#  'p60f': 'Descontento por ambiente perjudicial',
#  'p60g': 'Descontento por trabajar en la calle',
#  'p60h': 'Descontento por posibles accidentes',
#  'p60i': 'Descontento por las activ. que realiza',
#  'p60j': 'Descontento por pocas posibilidades de progreso',
#  'p60k': 'Descontento por malas relaciones laborales',
#  'p61b1': 'A cuál de las siguientes formas de seguridad social aporta actualmente',
#  'p61c1': 'Dispone computador portátil o de escritorio para realizar sus actividades diarias (Educativas, laborales, recreación, etc.)',
#  'p61c2': 'Dispone de Tablet para realizar sus actividades diarias (Educativas, laborales, recreación, etc.)',
#  'p61c3': 'Dispone de Smartphone o teléfono inteligente para realizar sus actividades diarias (Educativas, laborales, recreación, etc.)',
#  'p63': 'Ingresos - Patronos Cuenta Propia',
#  'p64a': 'Retiró bienes del negocio',
#  'p64b': 'Monto de retiro de bienes del negocio',
#  'p65': 'Monto gastado en funcionamiento negocio',
#  'p66': 'Ingreso de asalariados y/o empleados domésticos',
#  'p67': 'Descuentos de asalariados',
#  'p68a': 'Recibió ingreso en especies',
#  'p68b': 'Ingreso en especies de asalariados',
#  'p69': 'Ingreso ocup. secundaria - asalariados e independientes',
#  'p70a': 'Recibió pago en especies - trabajo secundario',
#  'p70b': 'Pago en especies - trabajo secundario',
#  'p71a': 'Recibió ingresos derivados del capital',
#  'p71b': 'Ingreso recibido por transacciones de capital',
#  'p72a': 'Recibe jubilación o pensiones',
#  'p72b': 'Ingreso por jubilación o pensiones',
#  'p73a': 'Recibió regalos o donaciones',
#  'p73b': 'Ingreso por regalos o donaciones - Monto',
#  'p74a': 'Recibió dinero del exterior',
#  'p74b': 'Ingreso del exterior - Monto',
#  'p75': 'Recibió el Bono de Desarrollo Humano',
#  'p76': 'Monto que recibió por el Bono de Desarrollo Humano',
#  'p77': 'Recibió el Bono por discapacidad (Joaquin Gallegos Lara  - BJGL)',
#  'p78': 'Monto recibido por el Bono por discapacidad (Joaquin Gallegos Lara - BJGL)',
#  'p79': 'Recibe el BONO DE PROTECCIÓN FAMILIAR',
#  'p80': 'Monto recibido por el BONO DE PROTECCIÓN FAMILIAR',
#  'p81': 'Recibe el BONO DE APOYO NUTRICIONAL',
#  'p82': 'Monto recibido por el APOYO NUTRICIONAL',
#  'sd01': 'Realizó USTED algún trabajo por paga o para obtener ganancias',
#  'sd021': 'La semana pasada que no tenía trabajo - Estudió o estuvo capacitándose',
#  'sd022': 'La semana pasada que no tenía trabajo - Hizo actividades de esparcimiento (deporte)',
#  'sd023': 'La semana pasada que no tenía trabajo - Realizó alguna gestión para buscar trabajo',
#  'sd024': 'La semana pasada que no tenía trabajo - Ayudó o se dedicó a otras labores del hogar o la familia',
#  'sd025': 'La semana pasada que no tenía trabajo - Ayudó como voluntario/a',
#  'sd026': 'La semana pasada que no tenía trabajo - Realizó trabajo agrícola, cría animales o pesca',
#  'sd027': 'La semana pasada que no tenía trabajo - Realizó manualidades o tejidos para la venta',
#  'sd028': 'La semana pasada que no tenía trabajo - Ayudó en algún negocio familiar',
#  'sd029': 'La semana pasada que no tenía trabajo - Dio clases particulares, tareas dirigidas pagadas',
#  'sd0210': 'La semana pasada que no tenía trabajo - Realizó venta de productos por internet, catálogo o venta directa',
#  'sd0211': 'La semana pasada que no tenía trabajo - Otro',
#  'sd03': 'El principal motivo por el que usted está sin trabajo es:',
#  'ced01a': 'Tiene cédula de identidad',
#  'ingrl': 'Ingreso Laboral',
#  'fexp': 'Factor de expansión',
#  'condact': 'Condición de actividad',
#  'secemp': 'Sectorización de los empleados (15 años y más)',
#  'empleo': 'Población con empleo',
#  'desempleo': 'Población con desempleo',
#  'grupo1': 'Grupo de Ocupación CIUO8 (población ocupada de 15 años y más)',
#  'rama1': 'Rama de Actividad CIIU4 (población ocupada de 15 años y más)',
#  'ingpc': 'Ingreso per cápita',
#  'pobreza': 'Pobreza',
#  'epobreza': 'Extrema Pobreza',
#  'nnivins': 'Nivel de instrucción',
#  'estrato': 'Estratos',
#  'upm': 'Unidad primaria de muestreo',
#  'id_vivienda': 'Identificador de vivienda',
#  'id_hogar': 'Identificador de hogar',
#  'id_persona': 'Identificador de persona',
#  'periodo': 'Periodo'}

# %%
# Leer codificaciones

meta_p.variable_value_labels
# Out:
# {'area': {1.0: ' Urbana', 2.0: ' Rural'},
#  'p01': {'10': ' Persona 10',
#   '20': ' Persona 20',
#   ' 1': ' Persona 1',
#   '11': ' Persona 11',
#   '21': ' Persona 21',
#   ' 2': ' Persona 2',
#   '12': ' Persona 12',
#   '22': ' Persona 22',
#   ' 3': ' Persona 3',
#   '13': ' Persona 13',
#   '23': ' Persona 23',
#   ' 4': ' Persona 4',
#   '14': ' Persona 14',
#   '24': ' Persona 24',
#   ' 5': ' Persona 5',
#   '15': ' Persona 15',
#   '25': ' Persona 25',
#   ' 6': ' Persona 6',
#   '16': ' Persona 16',
#   ' 7': ' Persona 7',
#   '17': ' Persona 17',
#   ' 8': ' Persona 8',
#   '18': ' Persona 18',
#   ' 9': ' Persona 9',
#   '19': ' Persona 19'},
#  'p02': {1.0: ' Hombre', 2.0: ' Mujer'},
#  'p03': {98.0: ' 98 y más', 99.0: ' No informa'},
#  'p04': {1.0: ' Jefe',
#   2.0: ' Cónyuge',
#   3.0: ' Hijo o Hija',
#   4.0: ' Yerno o nuera',
#   5.0: ' Nieto o nieta',
#   6.0: ' Padres o suegros',
#   7.0: ' Otros parientes',
#   8.0: ' Empleado(a) doméstico(a)',
#   9.0: ' Otros no parientes'},
#  'p05a': {1.0: ' IESS, seguro general',
#   2.0: ' IESS, seguro general voluntario',
#   3.0: ' IESS, seguro  campesino',
#   4.0: ' ISSFA, ISSPOL',
#   5.0: ' Seguro privado con hospitalización',
#   6.0: ' Seguro privado sin hospitalización',
#   7.0: ' AUS',
#   8.0: ' Seguros Municipales',
#   9.0: ' Seguro Ministerio Salud Pública',
#   10.0: ' Ninguno'},
#  'p05b': {1.0: ' IESS, seguro general',
#   2.0: ' IESS, seguro general voluntario',
#   3.0: ' IESS, seguro  campesino',
#   4.0: ' ISSFA, ISSPOL',
#   5.0: ' Seguro privado con hospitalización',
#   6.0: ' Seguro privado sin hospitalización',
#   7.0: ' AUS',
#   8.0: ' Seguros Municipales',
#   9.0: ' Seguro Ministerio Salud Pública',
#   10.0: ' Ninguno'},
#  'p06': {1.0: ' Casado(a)',
#   2.0: ' Separado(a)',
#   3.0: ' Divorciado(a)',
#   4.0: ' Viudo(a)',
#   5.0: ' Unión libre',
#   6.0: ' Soltero(a)'},
#  'p07': {1.0: ' Si', 2.0: ' No'},
#  'p08': {1.0: ' La mañana',
#   2.0: ' La tarde',
#   3.0: ' La Noche',
#   4.0: ' Jornada Integral',
#   5.0: ' Dos Jornadas',
#   6.0: ' A distancia'},
#  'p08a': {1.0: ' Aprendamos Juntos en casa',
#   2.0: ' Virtual, en linea, educación en casa',
#   3.0: ' Juntos aprendemos y nos cuidamos',
#   4.0: ' Todos de regreso a la Escuela'},
#  'p09': {1.0: ' Edad',
#   2.0: ' Terminó sus estudios',
#   3.0: ' Falta de recursos económicos',
#   4.0: ' Por fracaso escolar',
#   5.0: ' Por trabajo',
#   6.0: ' Por asistir a nivelación SENESCYT',
#   7.0: ' Por enfermedad o discapacidad',
#   8.0: ' Por ayudar en quehaceres del hogar',
#   9.0: ' La familia no le permite estudiar',
#   10.0: ' No hay establecimientos educación',
#   11.0: ' No está interesado en estudiar',
#   12.0: ' Por embarazo',
#   13.0: ' Por falta de cupo',
#   14.0: ' Por temor a los compañeros',
#   15.0: ' Por cuidado de los hijos',
#   16.0: 'Por falta de recursos tecnológicos (internet, computadora,celular)',
#   17.0: ' Otra'},
#  'p10a': {1.0: ' Ninguno',
#   2.0: ' Centro de alfabetización',
#   3.0: ' Jardín de infantes',
#   4.0: ' Primaria',
#   5.0: ' Educación Básica',
#   6.0: ' Secundaria',
#   7.0: ' Educación  Media',
#   8.0: ' Superior no universitario',
#   9.0: ' Superior Universitario',
#   10.0: ' Post-grado'},
#  'p11': {1.0: ' Si', 2.0: ' No'},
#  'p12a': {1.0: ' Si', 2.0: ' No'},
#  'p12b': {999999.0: ' NS'},
#  'p15': {1.0: ' Indígena',
#   2.0: ' Afroecuatoriano',
#   3.0: ' Negro',
#   4.0: ' Mulato',
#   5.0: ' Montuvio',
#   6.0: ' Mestizo',
#   7.0: ' Blanco',
#   8.0: ' Otra'},
#  'p15aa': {1.0: ' En esta ciudado  o parroquia rural',
#   2.0: ' En otro lugar del pais',
#   3.0: ' En otro pais'},
#  'cod_inf': {1.0: ' Persona 1',
#   2.0: ' Persona 2',
#   3.0: ' Persona 3',
#   4.0: ' Persona 4',
#   5.0: ' Persona 5',
#   6.0: ' Persona 6',
#   7.0: ' Persona 7',
#   8.0: ' Persona 8',
#   9.0: ' Persona 9',
#   10.0: ' Persona 10',
#   11.0: ' Persona 11',
#   12.0: ' Persona 12',
#   13.0: ' Persona 13',
#   14.0: ' Persona 14',
#   15.0: ' Persona 15',
#   16.0: ' Persona 16',
#   17.0: ' Persona 17',
#   18.0: ' Persona 18',
#   19.0: ' Persona 19',
#   20.0: ' Persona 20',
#   21.0: ' Persona 21',
#   22.0: ' Persona 22',
#   23.0: ' Persona 23',
#   24.0: ' Persona 24',
#   25.0: ' Persona 25'},
#  'p20': {1.0: ' Si', 2.0: ' No'},
#  'p21': {1.0: ' Atender negocio propio',
#   2.0: ' Fabricar algún producto',
#   3.0: ' Hacer algo en casa por un ingreso',
#   4.0: ' Brindar algún servicio',
#   5.0: ' Ayudar en algún negocio familiar',
#   6.0: ' Ayudar en el trabajo de algún familiar',
#   7.0: ' Aprendiz remunerado',
#   8.0: ' Labores agrícolas, cuidado animales',
#   9.0: ' Estudiante que realizó algún trabajo',
#   10.0: ' Trabajar para otra familia',
#   11.0: ' Otra actividad por un ingreso',
#   12.0: ' No realizó ninguna actividad'},
#  'p22': {1.0: ' Si', 2.0: ' No'},
#  'p23': {1.0: ' Vacaciones',
#   2.0: ' Enfermedad accidente',
#   3.0: ' Huelga o paro',
#   4.0: ' Licencia con sueldo',
#   5.0: ' Licencia sin sueldo',
#   6.0: ' Suspensión temporal del trabajo',
#   7.0: ' Otro'},
#  'p231': {1.0: ' Si', 2.0: ' No'},
#  'p232': {1.0: ' Si', 2.0: ' No'},
#  'p233': {1.0: ' 3 meses o menos',
#   2.0: ' Más de 3 meses',
#   3.0: ' No esta seguro de regresar'},
#  'p24': {999.0: ' No informan'},
#  'p25': {1.0: ' Su trabajo así lo exige',
#   2.0: ' No consiguió trabajo en otra parte',
#   3.0: ' No consiguió más trabajo',
#   4.0: ' Reducción actividades económicas',
#   5.0: ' Falta de materia prima',
#   6.0: ' Motivos de salud, familiares',
#   7.0: ' Por estudios',
#   8.0: ' Por huelga o paro',
#   9.0: ' No desea o no necesita trabajar más horas'},
#  'p251': {1.0: ' Si', 2.0: ' No'},
#  'p26': {1.0: ' Horario normal',
#   2.0: ' Horas extras',
#   3.0: ' Exceso trabajo',
#   4.0: ' Horas trabajo necesarias',
#   5.0: ' Otro'},
#  'p27': {1.0: ' Trabajar más horas en su trabajo actual',
#   2.0: ' Trabajar más horas en otro trabajo',
#   3.0: ' Cambiar el trabajo por otro con más horas',
#   4.0: ' No desea trabajar más horas'},
#  'p28': {1.0: ' Si', 2.0: ' No'},
#  'p29': {999.0: ' No informa'},
#  'p30': {1.0: ' Buscar más trabajo',
#   2.0: ' Registro en agencia de empleo',
#   3.0: ' Presentar solicitud a otros empleadores',
#   4.0: ' Pedir ayuda a amigos o familiares',
#   5.0: ' Buscar terreno, edificio,... para propia empresa',
#   6.0: ' Conseguir recursos financieros adicionales',
#   7.0: ' No ha realizado ninguna gestión'},
#  'p31': {1.0: ' Por que no trabaja jornada completa',
#   2.0: ' Inseguridad en su trabajo',
#   3.0: ' Desea ejercer su profesión',
#   4.0: ' Los ingresos no son suficientes',
#   5.0: ' Por otras causas'},
#  'p32': {1.0: ' Acudir a sitios de contratación temporal',
#   2.0: ' Hablar con amigos o parientes',
#   3.0: ' Buscar en la prensa o radio',
#   4.0: ' Acudir a agencias de empleo',
#   5.0: ' Tratar de establecer su propio taller, negocio',
#   6.0: ' Asistir a entrevistas',
#   7.0: ' Colocar carteles en tiendas o negocios',
#   8.0: ' Buscar por Internet',
#   9.0: ' Enviar hoja de vida',
#   10.0: ' Otra gestión',
#   11.0: ' No realizó ninguna gestión'},
#  'p33': {999.0: ' No sabe/ No informa'},
#  'p34': {1.0: ' Trabajo ocasional',
#   2.0: ' Tiene trabajo para empezar inmediatamente',
#   3.0: ' Espera respuesta a una gestión',
#   4.0: ' Espera respuesta de un empleador',
#   5.0: ' Espera cosecha o temporada de trabajo',
#   6.0: ' Piensa que no le darán trabajo',
#   7.0: ' No cree poder encontrar',
#   8.0: ' No tiene necesidad de trabajar',
#   9.0: ' No tiene tiempo',
#   10.0: ' Su cónyuge o familia no le permiten',
#   11.0: ' Está enfermo o incapacitado',
#   12.0: ' No está en edad de trabajar'},
#  'p341': {1.0: ' Si', 2.0: ' No'},
#  'p35': {1.0: ' Si', 2.0: ' No'},
#  'p351': {1.0: ' Si', 2.0: ' No'},
#  'p36': {1.0: ' Rentista',
#   2.0: ' Jubilado pensión',
#   3.0: ' Estudiante',
#   4.0: ' Ama de casa',
#   5.0: ' Incapacitado',
#   6.0: ' Otro'},
#  'p37': {1.0: ' Si', 2.0: ' No'},
#  'p38': {1.0: ' Liquidación empresa',
#   2.0: ' Despido intempestivo',
#   3.0: ' Renuncia voluntaria',
#   4.0: ' Supresión partidas',
#   5.0: ' Terminación contrato',
#   6.0: ' Fue mal en el negocio',
#   7.0: ' Terminó ciclo agrícola',
#   8.0: ' Se jubiló o pensionaron',
#   9.0: ' Otro'},
#  'p381': {1.0: ' Si', 2.0: ' No'},
#  'p39': {999.0: ' No sabe/ No informa'},
#  'p40': {9999.0: ' No informa'},
#  'p41': {9999.0: ' No informa'},
#  'p42': {1.0: ' Empleado de gobierno',
#   2.0: ' Empleado privado',
#   3.0: ' Empleado terciarizado',
#   4.0: ' Jornalero o peón',
#   5.0: ' Patrono',
#   6.0: ' Cuenta Propia',
#   7.0: ' Trabajador del hogar no remunerado',
#   8.0: ' Trabajador no del hogar no remunerado',
#   9.0: ' Ayudante no remunerado de asalariado/jornalero',
#   10.0: ' Empleado(a) Doméstico(a)'},
#  'p42a': {1.0: ' Si', 2.0: ' No'},
#  'p43': {1.0: 'Con nombramiento',
#   2.0: 'Con contrato permanente / indefinido / estable o de planta',
#   3.0: ' Con contrato temporal, ocasional o eventual',
#   4.0: ' Por obra, a destajo',
#   5.0: ' Por horas',
#   6.0: ' Por jornal'},
#  'p44a': {1.0: ' Si', 2.0: ' No'},
#  'p44b': {1.0: ' Si', 2.0: ' No'},
#  'p44c': {1.0: ' Si', 2.0: ' No'},
#  'p44d': {1.0: ' Si', 2.0: ' No'},
#  'p44e': {1.0: ' Si', 2.0: ' No'},
#  'p44f': {1.0: ' Si', 2.0: ' No'},
#  'p44g': {1.0: ' Si', 2.0: ' No'},
#  'p44h': {1.0: ' Si', 2.0: ' No'},
#  'p44i': {1.0: ' Si', 2.0: ' No'},
#  'p44j': {1.0: ' Si', 2.0: ' No'},
#  'p44k': {1.0: ' Si', 2.0: ' No'},
#  'p45': {99.0: ' No informa'},
#  'p46': {1.0: ' Local patrono',
#   2.0: ' Obra en construcción',
#   3.0: ' Se desplaza',
#   4.0: ' En la calle',
#   5.0: ' Kiosco calle',
#   6.0: ' Local propio o arrendado',
#   7.0: ' Local cooperativa u asociación',
#   8.0: ' Vivienda distinta a la suya',
#   9.0: ' Su vivienda',
#   10.0: ' Finca o terreno',
#   11.0: ' Finca terreno ajeno',
#   12.0: ' Finca terreno o establecimiento comunal'},
#  'p47a': {1.0: ' Menos de 100', 2.0: ' 100 y más'},
#  'p48': {1.0: ' Registros contables',
#   2.0: ' Cuaderno de cuentas',
#   3.0: ' No lleva contabilidad',
#   4.0: ' No sabe'},
#  'p49': {1.0: ' Si', 2.0: ' No', 3.0: ' No sabe'},
#  'p50': {1.0: ' Uno', 2.0: ' Más de uno'},
#  'p51a': {999.0: ' No informan'},
#  'p51b': {999.0: ' No informan'},
#  'p51c': {999.0: ' No informan'},
#  'p52': {9999.0: ' No informa'},
#  'p53': {9999.0: ' No informa'},
#  'p54': {1.0: ' Empleado de gobierno',
#   2.0: ' Empleado privado',
#   3.0: ' Empleado terciarizado',
#   4.0: ' Jornalero o peón',
#   5.0: ' Patrono',
#   6.0: ' Cuenta Propia',
#   7.0: ' Trabajador del hogar no remunerado',
#   8.0: ' Trabajador no del hogar no remunerado',
#   9.0: ' Ayudante no remunerado de asalariado/jornalero',
#   10.0: ' Empleado(a) Doméstico(a)'},
#  'p54a': {1.0: ' Si', 2.0: ' No'},
#  'p55': {1.0: ' Local patrono',
#   2.0: ' Obra en construcción',
#   3.0: ' Se desplaza',
#   4.0: ' En la calle',
#   5.0: ' Kiosco calle',
#   6.0: ' Local propio o arrendado',
#   7.0: ' Local cooperativa u asociación',
#   8.0: ' Vivienda distinta a la suya',
#   9.0: ' Su vivienda',
#   10.0: ' Finca o terreno',
#   11.0: ' Finca terreno ajeno',
#   12.0: ' Finca terreno o establecimiento comunal'},
#  'p56a': {1.0: ' Menos de 100', 2.0: ' 100 y más'},
#  'p57': {1.0: ' Registros contables',
#   2.0: ' Cuaderno de cuentas',
#   3.0: ' No lleva contabilidad',
#   4.0: ' No sabe'},
#  'p58': {1.0: ' Si', 2.0: ' No', 3.0: ' No sabe'},
#  'p59': {1.0: ' Contento',
#   2.0: ' Poco contento',
#   3.0: ' Descontento pero conforme',
#   4.0: ' Totalmente descontento',
#   5.0: ' No sabe, no responde'},
#  'p60a': {1.0: ' Si', 2.0: ' No'},
#  'p60b': {1.0: ' Si', 2.0: ' No'},
#  'p60c': {1.0: ' Si', 2.0: ' No'},
#  'p60d': {1.0: ' Si', 2.0: ' No'},
#  'p60e': {1.0: ' Si', 2.0: ' No'},
#  'p60f': {1.0: ' Si', 2.0: ' No'},
#  'p60g': {1.0: ' Si', 2.0: ' No'},
#  'p60h': {1.0: ' Si', 2.0: ' No'},
#  'p60i': {1.0: ' Si', 2.0: ' No'},
#  'p60j': {1.0: ' Si', 2.0: ' No'},
#  'p60k': {1.0: ' Si', 2.0: ' No'},
#  'p61b1': {1.0: ' IESS General',
#   2.0: ' IESS Voluntario',
#   3.0: ' Seguro Campesino',
#   4.0: ' Seguro del ISSFA o ISSPOL',
#   5.0: ' No aporta',
#   6.0: ' No sabe'},
#  'p64a': {1.0: ' Si', 2.0: ' No'},
#  'p68a': {1.0: ' Si', 2.0: ' No'},
#  'p70a': {1.0: ' Si', 2.0: ' No'},
#  'p71a': {1.0: ' Si', 2.0: ' No'},
#  'p72a': {1.0: ' Si', 2.0: ' No'},
#  'p73a': {1.0: ' Si', 2.0: ' No'},
#  'p74a': {1.0: ' Si', 2.0: ' No'},
#  'p75': {1.0: ' Si', 2.0: ' No'},
#  'p76': {999999.0: ' NS'},
#  'p77': {1.0: ' Si', 2.0: ' No'},
#  'p78': {999999.0: ' No informa'},
#  'sd01': {1.0: ' Si', 2.0: ' No'},
#  'sd021': {1.0: ' Si', 2.0: ' No'},
#  'sd022': {1.0: ' Si', 2.0: ' No'},
#  'sd023': {1.0: ' Si', 2.0: ' No'},
#  'sd024': {1.0: ' Si', 2.0: ' No'},
#  'sd025': {1.0: ' Si', 2.0: ' No'},
#  'sd026': {1.0: ' Si', 2.0: ' No'},
#  'sd027': {1.0: ' Si', 2.0: ' No'},
#  'sd028': {1.0: ' Si', 2.0: ' No'},
#  'sd029': {1.0: ' Si', 2.0: ' No'},
#  'sd0210': {1.0: ' Si', 2.0: ' No'},
#  'sd0211': {1.0: ' Si', 2.0: ' No'},
#  'sd03': {1.0: ' Despido/Renuncia obligatoria',
#   2.0: ' Terminación de contrato',
#   3.0: ' Renuncia voluntaria',
#   4.0: ' Cierre/clausura de la empresa donde trabajaba',
#   5.0: ' Quiebre o cierre de negocio',
#   6.0: ' Terminación de ciclo agrícola o temporada del trabajo',
#   7.0: ' Condiciones climáticas (lluvias, sequías, inundaciones, heladas)',
#   8.0: ' Antes no tuvo necesidad de trabajar',
#   9.0: ' Otro, (especificar)'},
#  'ced01a': {1.0: ' Si', 2.0: ' No', 3.0: ' No responde'},
#  'ingrl': {-1.0: 'Gasta mas de lo que gana', 999999.0: 'No informa'},
#  'condact': {0.0: 'Menores de 15 años',
#   1.0: 'Empleo Adecuado/Pleno',
#   2.0: 'Subempleo por insuficiencia de tiempo de trabajo',
#   3.0: 'Subempleo por insuficiencia de ingresos',
#   4.0: 'Otro empleo no pleno',
#   5.0: 'Empleo no remunerado',
#   6.0: 'Empleo no clasificado',
#   7.0: 'Desempleo abierto',
#   8.0: 'Desempleo oculto',
#   9.0: 'Población Económicamente Inactiva'},
#  'empleo': {1.0: 'Población con empleo'},
#  'desempleo': {1.0: 'Población con desempleo'},
#  'secemp': {1.0: 'Sector Formal',
#   2.0: 'Sector Informal',
#   3.0: 'Empleo Doméstico',
#   4.0: 'No Clasificados por Sector'},
#  'grupo1': {1.0: 'Personal direct./admin. pública y empresas',
#   2.0: 'Profesionales científicos e intelectuales',
#   3.0: 'Técnicos y profesionales de nivel medio',
#   4.0: 'Empleados de oficina',
#   5.0: 'Trabajad. de los servicios y comerciantes',
#   6.0: 'Trabajad. calificados agropecuarios y pesqueros',
#   7.0: 'Oficiales operarios y artesanos',
#   8.0: 'Operadores de instalac. máquinas y montad.',
#   9.0: 'Trabajadores no calificados, ocupaciones elementales',
#   10.0: 'Fuerzas Armadas',
#   99.0: 'No especificado'},
#  'rama1': {1.0: 'A. Agricultura, ganadería caza y silvicultura y pesca',
#   2.0: 'B. Explotación de minas y canteras',
#   3.0: 'C. Industrias manufactureras',
#   4.0: 'D. Suministros de electricidad, gas, aire acondicionado',
#   5.0: 'E. Distribución de agua, alcantarillado',
#   6.0: 'F. Construcción',
#   7.0: 'G. Comercio, reparación vehículos',
#   8.0: 'H. Transporte y almacenamiento',
#   9.0: 'I. Actividades de alojamiento y servicios de comida',
#   10.0: 'J. Información y comunicación',
#   11.0: 'K. Actividades financieras y de seguros',
#   12.0: 'L. Actividades inmobiliarias',
#   13.0: 'M. Actividades profesionales, científicas y técnicas',
#   14.0: 'N. Actividades y servicios administrativos y de apoyo',
#   15.0: 'O .Administración pública, defensa y seguridad social',
#   16.0: 'P. Enseñanza',
#   17.0: 'Q. Actividades, servicios sociales y de salud',
#   18.0: 'R. Artes, entretenimiento y recreación',
#   19.0: 'S. Otras actividades de servicios',
#   20.0: 'T  Actividades en hogares privados con servicio doméstico',
#   21.0: 'U  Actividades de organizaciones extraterritoriales',
#   22.0: 'No especificado'},
#  'nnivins': {1.0: 'Ninguno',
#   2.0: 'Centro de Alfabetización',
#   3.0: 'Educación Básica',
#   4.0: 'Educación Media/Bachillerato',
#   5.0: 'Superior'},
#  'periodo': {202104.0: 'abr-21'}}

# %% [markdown]
# ## Mejorar la calidad de la base

# %%
df_persona.rename(columns=meta_p.column_names_to_labels, inplace=True) # meta.column_names_to_labels sirve como diccionarios
df_consumidor.rename(columns=meta_c.column_names_to_labels, inplace=True)
df_vivienda.rename(columns=meta_v.column_names_to_labels, inplace=True)

# %%
"""Si deseamos decodificar los valores de variable""" 

# Cambiar codigos por valores
# df_persona = pyd.set_value_labels(df_persona, meta)

# https://stackoverflow.com/questions/62962795/how-to-read-spss-aka-sav-in-python
# Out:
# 'Si deseamos decodificar los valores de variable'

# %%
for i in df_persona.columns:
    print(i)
# Out:
# Area
# Ciudad
# Conglomerado
# Panelm
# Vivienda
# Hogar
# Persona
# Sexo
# Edad
# Relación de parentesco
# Seguro Social - Alternativa 1
# Seguro Social - Alternativa 2
# Estado civil
# Asiste a clases
# Jornada a la que asiste
# Modalidad de estudio a la que asiste
# Tipo de conexión para actividades educativas
# Razón por la que no asiste
# Nivel de instrucción
# Año aprobado
# Sabe leer y escribir
# Por sus estudios obtuvo algún título
# Qué título obtuvo
# Cómo se considera
# Donde nació
# Lugar de nacimiento
# Código del Informante
# Trabajó la semana pasada
# Actividad que realizó para ayudar en su hogar
# Tiene trabajo del cual estuvo ausente
# Razón por la que no trabajó
# Razón relacionada con el COVID19
# Continua(ó) recibiendo algún ingreso durante ausencia del trabajo
# Desde que dejó de trabajar hasta que espera regresar ¿Cuánto tiempo estará (...) ausente
# Horas de trabajo en la semana anterior
# Razón por la que trabajó menos de 40 horas
# Razón relacionada con el COVID19
# Razón por la que trabajó más de 40 horas
# Desea trabajar más horas
# Está disponible para trabajar horas adicionales
# Cuántas horas a la semana estaría disponible para trabajar
# Gestión realizada para cambiar la situación actual de trabajo
# Razón por la que busca cambiar la situación actual de trabajo
# Buscó trabajo el mes anterior
# Semanas que busca trabajo
# Razón por la que no buscó trabajo
# Razón relacionada con el COVID19
# Desea trabajar y está dispuesto a hacerlo
# Razón relacionada con el COVID19
# Condición de inactividad
# Trabajó anteriormente
# Motivos por los que dejó de trabajar
# Razón relacionada con el COVID19
# Número de semanas que no trabaja
# Rama de actividad
# Grupo de ocupación
# Categoría de ocupación
# Es socio de cooperativa o asociación
# El trabajo que tiene es
# Recibe alimentación
# Recibe vivienda
# Recibe transporte
# Recibe vacaciones
# Recibe ropa de trabajo
# Recibe seguro social
# Recibe seguro médico
# Recibe guardería
# Recibe cursos de capacitación
# Recibe 13er sueldo
# Recibe 14to sueldo
# Cuántos años trabaja
# Sitio de trabajo
# Tamaño del establecimiento
# Número personas trabajan en el establecimiento
# En el establecimiento se lleva
# El establecimiento tiene RUC
# Número de trabajos
# Horas de trabajo principal
# Horas de trabajo secundario
# Horas de otros trabajos
# Rama de actividad - trabajo secundario
# Grupo de ocupación - trabajo secundario
# Categoría de ocupación - trabajo secundario
# Es socio de cooperativa o asociación - trabajo secundario
# Sitio de trabajo secundario
# Tamaño establecimiento - trabajo secundario
# Personas que trabajan - trabajo secundario
# En el establecimiento de trabajo secundario se lleva
# El establecimiento de trabajo secundario tiene RUC
# Cómo se siente en su trabajo
# Descontento por ingresos bajos
# Descontento por muchas horas de trabajo
# Descontento por horarios inconvenientes
# Descontento por sobrecarga de trabajo
# Descontento por no tener estabilidad
# Descontento por ambiente perjudicial
# Descontento por trabajar en la calle
# Descontento por posibles accidentes
# Descontento por las activ. que realiza
# Descontento por pocas posibilidades de progreso
# Descontento por malas relaciones laborales
# A cuál de las siguientes formas de seguridad social aporta actualmente
# Dispone computador portátil o de escritorio para realizar sus actividades diarias (Educativas, laborales, recreación, etc.)
# Dispone de Tablet para realizar sus actividades diarias (Educativas, laborales, recreación, etc.)
# Dispone de Smartphone o teléfono inteligente para realizar sus actividades diarias (Educativas, laborales, recreación, etc.)
# Ingresos - Patronos Cuenta Propia
# Retiró bienes del negocio
# Monto de retiro de bienes del negocio
# Monto gastado en funcionamiento negocio
# Ingreso de asalariados y/o empleados domésticos
# Descuentos de asalariados
# Recibió ingreso en especies
# Ingreso en especies de asalariados
# Ingreso ocup. secundaria - asalariados e independientes
# Recibió pago en especies - trabajo secundario
# Pago en especies - trabajo secundario
# Recibió ingresos derivados del capital
# Ingreso recibido por transacciones de capital
# Recibe jubilación o pensiones
# Ingreso por jubilación o pensiones
# Recibió regalos o donaciones
# Ingreso por regalos o donaciones - Monto
# Recibió dinero del exterior
# Ingreso del exterior - Monto
# Recibió el Bono de Desarrollo Humano
# Monto que recibió por el Bono de Desarrollo Humano
# Recibió el Bono por discapacidad (Joaquin Gallegos Lara  - BJGL)
# Monto recibido por el Bono por discapacidad (Joaquin Gallegos Lara - BJGL)
# Recibe el BONO DE PROTECCIÓN FAMILIAR
# Monto recibido por el BONO DE PROTECCIÓN FAMILIAR
# Recibe el BONO DE APOYO NUTRICIONAL
# Monto recibido por el APOYO NUTRICIONAL
# Realizó USTED algún trabajo por paga o para obtener ganancias
# La semana pasada que no tenía trabajo - Estudió o estuvo capacitándose
# La semana pasada que no tenía trabajo - Hizo actividades de esparcimiento (deporte)
# La semana pasada que no tenía trabajo - Realizó alguna gestión para buscar trabajo
# La semana pasada que no tenía trabajo - Ayudó o se dedicó a otras labores del hogar o la familia
# La semana pasada que no tenía trabajo - Ayudó como voluntario/a
# La semana pasada que no tenía trabajo - Realizó trabajo agrícola, cría animales o pesca
# La semana pasada que no tenía trabajo - Realizó manualidades o tejidos para la venta
# La semana pasada que no tenía trabajo - Ayudó en algún negocio familiar
# La semana pasada que no tenía trabajo - Dio clases particulares, tareas dirigidas pagadas
# La semana pasada que no tenía trabajo - Realizó venta de productos por internet, catálogo o venta directa
# La semana pasada que no tenía trabajo - Otro
# El principal motivo por el que usted está sin trabajo es:
# Tiene cédula de identidad
# Ingreso Laboral
# Factor de expansión
# Condición de actividad
# Sectorización de los empleados (15 años y más)
# Población con empleo
# Población con desempleo
# Grupo de Ocupación CIUO8 (población ocupada de 15 años y más)
# Rama de Actividad CIIU4 (población ocupada de 15 años y más)
# Ingreso per cápita
# Pobreza
# Extrema Pobreza
# Nivel de instrucción
# Estratos
# Unidad primaria de muestreo
# Identificador de vivienda
# Identificador de hogar
# Identificador de persona
# Periodo

# %% [markdown]
# # Tipología del hogar, según metodología INEC

# %%
'''Hay que verificar que si en una vivienda existen al menos dos hogares o no.'''

# Visualizamos los datos 

df_persona[['Ciudad', 'Identificador de vivienda', 'Identificador de hogar', 'Persona', 'Relación de parentesco']].head(20)
# Out:
#       Ciudad Identificador de vivienda Identificador de hogar Persona  \
# 0   200250.0         20025000002200502     200250000022005021      01
# 1   200250.0         20025000002200502     200250000022005021      02
# 2   200250.0         20025000002200503     200250000022005031      01
# 3   200250.0         20025000002200503     200250000022005031      02
# 4   200250.0         20025000002200503     200250000022005031      03
# 5   200250.0         20025000002200505     200250000022005051      01
# 6   200250.0         20025000002200505     200250000022005051      02
# 7   200250.0         20025000002200505     200250000022005051      03
# 8   200250.0         20025000002200506     200250000022005061      01
# 9   200250.0         20025000002200506     200250000022005061      02
# 10  200250.0         20025000002200506     200250000022005061      03
# 11  200250.0         20025000002200507     200250000022005071      01
# 12  200250.0         20025000002200507     200250000022005071      02
# 13  200250.0         20025000002200508     200250000022005081      01
# 14  200250.0         20025000002200508     200250000022005081      02
# 15  200250.0         20025000002200508     200250000022005081      03
# 16  200350.0         20035000004900501     200350000049005011      01
# 17  200350.0         20035000004900501     200350000049005011      02
# 18  200350.0         20035000004900502     200350000049005021      01
# 19  200350.0         20035000004900502     200350000049005021      02
#
#    Relación de parentesco
# 0                    Jefe
# 1             Hijo o Hija
# 2                    Jefe
# 3                 Cónyuge
# 4             Hijo o Hija
# 5                    Jefe
# 6             Hijo o Hija
# 7        Padres o suegros
# 8                    Jefe
# 9                 Cónyuge
# 10            Hijo o Hija
# 11                   Jefe
# 12                Cónyuge
# 13                   Jefe
# 14                Cónyuge
# 15            Hijo o Hija
# 16                   Jefe
# 17                Cónyuge
# 18                   Jefe
# 19            Hijo o Hija

# %% [markdown]
# # Número de personas en el hogar

# %%
# Para esto, vamos a desagregar los datos en en dos niveles jerárquicos: El nivel 1, Identificador de vivienda, que contiene 
# a su vez al nivel 2, Identificador de hogar. Entonces, el conteo de identificadores de hogar será el número de persoans, 
# pues a cada persona de ese higar se le asigna el mismo identificador de hogar. Luego, Cuando contemos el número de 
# identificadores de hogar dentro de la vivienda obtendrémos el número de hogares.

des = ['Identificador de vivienda', 'Identificador de hogar']
count_parentezco = df_persona.groupby(by=des).size().reset_index(name="Número de personas")
count_parentezco = count_parentezco[des+['Número de personas']].head(10).sort_values(by=['Identificador de vivienda'])
count_parentezco
# Out:
#   Identificador de vivienda Identificador de hogar  Número de personas
# 0         01015000050300901     010150000503009011                   3
# 1         01015000050300902     010150000503009021                   8
# 2         01015000050300903     010150000503009031                   8
# 3         01015000050300904     010150000503009041                   3
# 4         01015000050300905     010150000503009051                   4
# 5         01015000050300906     010150000503009061                   1
# 6         01015000050300908     010150000503009081                   4
# 7         01015000110100501     010150001101005011                   3
# 8         01015000110100502     010150001101005021                   4
# 9         01015000110100503     010150001101005031                   4

# %%
# Para hacer una verificación: filtramos la base para el primer identificador de hogar de la tabla de arriba

df_persona[df_persona['Identificador de vivienda'] == '01015000050300901']
# Out:
#          Area   Ciudad Conglomerado   Panelm Vivienda       Hogar Persona  \
# 2438   Urbana  10150.0       000503  Panel I       01   Hogar Uno      01
# 2439   Urbana  10150.0       000503  Panel I       01   Hogar Uno      02
# 2440   Urbana  10150.0       000503  Panel I       01   Hogar Uno      03
#
#          Sexo  Edad Relación de parentesco  ... Ingreso per cápita Pobreza  \
# 2438   Hombre  63.0                   Jefe  ...          33.333333   POBRE
# 2439    Mujer  62.0                Cónyuge  ...          33.333333   POBRE
# 2440    Mujer  34.0            Hijo o Hija  ...          33.333333   POBRE
#
#      Extrema Pobreza Nivel de instrucción Estratos  \
# 2438       INDIGENTE     Educación Básica     2712
# 2439       INDIGENTE     Educación Básica     2712
# 2440       INDIGENTE             Superior     2712
#
#      Unidad primaria de muestreo Identificador de vivienda  \
# 2438                010150000503         01015000050300901
# 2439                010150000503         01015000050300901
# 2440                010150000503         01015000050300901
#
#      Identificador de hogar Identificador de persona  Periodo
# 2438     010150000503009011     01015000050300901101   dic-20
# 2439     010150000503009011     01015000050300901102   dic-20
# 2440     010150000503009011     01015000050300901103   dic-20
#
# [3 rows x 164 columns]

# %%
# Ahora, procedemos a ver si hay al menos dos hogares por vivienda
ver = count_parentezco.groupby(by=['Identificador de vivienda', 'Identificador de hogar']).size().reset_index(name="cuenta")
ver[ver['cuenta'] >= 2]
# Es igual de válido usar: 
# count_parentezco.groupby(by=['Identificador de vivienda'])['Identificador de hogar'].count().reset_index(name="cuenta")
# Out:
# Empty DataFrame
# Columns: [Identificador de vivienda, Identificador de hogar, cuenta]
# Index: []

# %% [markdown]
# ###### Ahora podemos estar seguros de que los datos a tratar se pueden empaquetar por el código de hogar.
